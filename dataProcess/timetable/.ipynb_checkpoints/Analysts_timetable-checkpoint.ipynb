# %%
import pandas as pd

# %%
file = pd.read_csv('timetable_20200410.csv',dtype={'stop_id': str,'block_id':str,'parent_station':str})

# %%
file.describe()
# Out:
#        start_date    end_date  route_type   direction_id  stop_sequence  \
# count    156600.0    156600.0    156600.0  156600.000000  156600.000000
# mean   20200410.0  20200413.0         2.0       0.475511      46.111360
# std           0.0         0.0         0.0       0.499402      37.606233
# min    20200410.0  20200413.0         2.0       0.000000       0.000000
# 25%    20200410.0  20200413.0         2.0       0.000000      18.000000
# 50%    20200410.0  20200413.0         2.0       0.000000      36.000000
# 75%    20200410.0  20200413.0         2.0       1.000000      66.000000
# max    20200410.0  20200413.0         2.0       1.000000     283.000000
#
#          pickup_type  drop_off_type       stop_lat       stop_lon  \
# count  156600.000000  156600.000000  156600.000000  156600.000000
# mean        0.273091       0.272388     -33.841271     151.059935
# std         0.445548       0.445190       0.286777       0.272657
# ...

# %%
file.head()
# Out:
#    start_date  end_date arrival_time departure_time route_id route_short_name  \
# 0    20200410  20200413     08:12:00       08:12:30   APS_1a               T8
# 1    20200410  20200413     08:02:01       08:03:01   APS_1a               T8
# 2    20200410  20200413     08:20:00       08:21:00   APS_1a               T8
# 3    20200410  20200413     09:17:00       09:18:00   APS_1a               T8
# 4    20200410  20200413     08:51:00       08:51:30   APS_1a               T8
#
#                         route_long_name  route_type route_color  \
# 0  City Circle to Macarthur via Airport           2      00954C
# 1  City Circle to Macarthur via Airport           2      00954C
# 2  City Circle to Macarthur via Airport           2      00954C
# 3  City Circle to Macarthur via Airport           2      00954C
# 4  City Circle to Macarthur via Airport           2      00954C
#
#   route_text_color  ... wheelchair_boarding monday tuesday  wednesday  \
# ...
